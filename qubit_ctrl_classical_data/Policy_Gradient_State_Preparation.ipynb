# %%
import numpy as np
from scipy.linalg import expm

# fix seed
seed=0 
np.random.seed(seed)

# fix output array
np.set_printoptions(suppress=True,precision=2)

# %% [markdown]
# # Deep Policy Gradient (PG)
#
#
# In this notebook, our goal is to implement the REINFORCE algorithm for policy gradient using [JAX](https://jax.readthedocs.io/en/latest/).
#
# We will apply this RL algorithm to control a single quantum bit of information (qubit) in the presence of different kinds of noise and spontaneous emission.
#
# ## The REINFORCE Algorithm
#
# The reinforcement learning objective $J$ is the expected total return, following the policy $\pi$. If the transition probability is denoted by $p(s'|s,a)$, and the initial state distribution is $p(s_0)$, the probability for a trajectory $\tau = (s_0,a_0,r_1,s_1,a_1,\dots,s_{T-1},a_{T-1},r_T,s_T)$ to occur can be written as
#
# $$
# P_\pi(\tau) = p(s_0)\prod_{t=1}^T \pi(a_t|s_t)p(s_{t+1}|s_t,a_t).
# $$
#
# The RL objective then takes the form
#
# $$
# \mathbf J = \mathbb{E}_{\tau\sim P_\pi} \left[ \mathbf G(\tau) | s_{t=0}=s_0 \right],\qquad \mathbf G(\tau)=\sum_{t=1}^T r(s_t,a_t).
# $$
#
# Policy gradient methods in RL approximate directly the policy $\pi\approx\pi_\theta$ using a variational ansatz, parametrized by some unknown parameters $\theta$ (e.g., the weights and biases of a neural network). The goal is then to find those optimal parameters $\theta$, which maximize the RL objective $\mathbf J(\theta)$. To define an update rule for $\theta$, we can use gradient ascent. This requires us to evaluate the gradient of the RL objective w.r.t. the parameters $\theta$:
#
# $$
# \mathbf J = \mathbb{E}_{\tau\sim P_\pi} \left[ \mathbf G(\tau) | s_{t=0}=s_0 \right]
#     = \int\mathcal{D}\tau\; P_{\pi}(\tau)\; G(\tau).
# $$
# In a model-free setting, we don't have access to the transition probabilities $p(s'|s,a)$ and this requires us to be able to estimate the gradients from samples. This can be accomplished by noticing that $\nabla_\theta P_{\pi_\theta} = P_{\pi_\theta} \nabla_\theta \log P_{\pi_\theta}$ (almost everywhere, i.e. up to a set of measure zero):
#
# $$
# \nabla_\theta \mathbf J(\theta) = \nabla_\theta \mathbb{E}_{\tau\sim P_\pi} \left[ \sum_{t=1}^T r(s_t,a_t) | s_{t=0}=s_0 \right]
# = \nabla_\theta \int\mathcal{D}\tau\; P_{\pi_\theta}(\tau)\; \mathbf G(\tau)
# = \int\mathcal{D}\tau\; \nabla_\theta P_{\pi_\theta}(\tau)\; \mathbf G(\tau).
# $$
# Since the initial state distribution $p(s_0)$ and the transition probabilities $p(s_{t+1}|s_t,a_t)$ are independent of $\theta$, using the definition of $P_{\pi_\theta}$, we see that $\nabla_\theta P_{\pi_\theta}(\tau) = \nabla_\theta \pi_\theta(\tau)$ where $\pi_\theta(\tau) = \prod_{t=1}^T \pi_\theta(a_t|s_t)$.
#
# We can therefore use Monte Carlo sampling to estimate the gradients directly from a sample of trajectories $\{\tau_j\}_{j=1}^N$ using the policy $\pi_\theta(\tau)$:
# $$
#     \nabla_\theta \mathbf J(\theta) = \mathbb{E}_{\tau\sim P_\pi} \left[\nabla_\theta \log \pi_\theta(\tau)\; \mathbf G(\tau)\right]
#     \approx \frac{1}{N}\sum_{j=1}^N \nabla_\theta \log \pi_\theta(\tau_j)\; \mathbf G(\tau_j)
#     = \frac{1}{N}\sum_{j=1}^N \left( \sum_{t=1}^T \nabla_\theta\; \pi_\theta(a^j_t|s^j_t) \sum_{t'=1}^T r(a^j_{t'},s^j_{t'}) \right),
# $$
# where in the last equality we used $\log \pi_\theta(\tau) = \log \prod_{t=1}^T \pi_\theta(a_t|s_t) = \sum_{t=1}^T \pi_\theta(a^j_t|s^j_t)$, together with the definition of the total return $\mathbf G(\tau)$ above.
#
# To alleviate the problem with the large variance of the gradient estimate, one can introduce a baseline $b=N^{-1}\sum_j \sum_{t'=t}^T r(a^j_{t'}|s^j_{t'})$, defined as the average return over the sample. The policy gradient (PG) update then takes the form
#
# $$
# \nabla_\theta \mathbf J(\theta)
# \approx \frac{1}{N}\sum_{j=1}^N \sum_{t=1}^T \nabla_\theta \log \pi_\theta(a^j_t|s^j_t) \left[\sum_{t'=t}^T r(a^j_{t'}|s^j_{t'})) - b\right].
# $$
#
# One can show that adding this baseline term does not change the expectation value $\nabla_\theta \mathbf J(\theta) = \mathbb{E}_{\tau\sim P_\pi} \left[\nabla_\theta \log \pi_\theta(\tau)\; \mathbf G(\tau)\right]$.
#
# The corresponding gradient *ascent* update rule reads as
#
# $$
# \theta \leftarrow \theta + \alpha \nabla_\theta \mathbf J(\theta),
# $$
# for some step size (or learning rate) $\alpha$.

# %% [markdown]
# ## Qubit Environment
#
# Let us define the qubit environment that models the action of gates on the state of the two-level system (2LS).
#
# ### Basic Definitions
#
# The state of a qubit $|\psi\rangle\in\mathbb{C}^2$ is modeled by a two-dimensional complex-valued vector with unit norm: $\langle\psi|\psi\rangle:=\sqrt{|\psi_1|^2+|\psi_2|^2}=1$. Every qubit state is uniquely described by two angles $\theta\in[0,\pi]$ and $\varphi\in[0,2\pi)$:
#
# \begin{eqnarray}
# |\psi\rangle=
# \begin{pmatrix}
# \psi_1 \\ \psi_2
# \end{pmatrix}=
# \mathrm{e}^{i\alpha}
# \begin{pmatrix}
# \cos\frac{\theta}{2} \\
# \mathrm{e}^{i\varphi}\sin\frac{\theta}{2}
# \end{pmatrix}
# \end{eqnarray}
#
# The overall phase $\alpha$ of a single quantum state has no physical meaning.
# Thus, any qubit state can be pictured as an arrow on the unit sphere (called the Bloch sphere) with angular coordinates $(\theta,\varphi)$.
#
# To operate on qubits, we use quantum gates. Quantum gates are represented as unitary transformations $U\in \mathrm{U(2)}$, where $\mathrm{U(2)}$ is the unitary group. Gates act on qubit states by matrix multiplication to transform an input state $|\psi\rangle$ to the output state $|\psi'\rangle$: $|\psi'\rangle=U|\psi\rangle$. For this problem, we consider four gates and their inverse:
#
# \begin{equation}
# U_0=\boldsymbol{1},\qquad
# U_x=\mathrm{exp}(-i\delta t \sigma^x/2),\qquad
# U_y=\mathrm{exp}(-i\delta t \sigma^y/2),\qquad
# U_z=\mathrm{exp}(-i\delta t \sigma^z/2),
# \end{equation}
#
# where $\delta t$ is a fixed time step, $\mathrm{exp}(\cdot)$ is the matrix exponential, $\boldsymbol{1}$ is the identity, and the Pauli matrices are defined as
#
# \begin{equation}
# \boldsymbol{1}=\begin{pmatrix}
# 1 & 0 \\ 0 & 1
# \end{pmatrix}
# ,\qquad
# \sigma^x=\begin{pmatrix}
# 0 & 1 \\ 1 & 0
# \end{pmatrix}
# ,\qquad
# \sigma^y=\begin{pmatrix}
# 0 & -i \\ i & 0
# \end{pmatrix}
# ,\ \qquad
# \sigma^z=\begin{pmatrix}
# 1 & 0 \\ 0 & -1
# \end{pmatrix}
# \end{equation}
#
# To determine if a qubit, described by the state $|\psi\rangle$, is in a desired target state $|\psi_\mathrm{target}\rangle$, we compute the fidelity
#
# \begin{eqnarray}
# F=|\langle\psi_\mathrm{target}|\psi\rangle|^2 = |(\psi_\mathrm{target})^\ast_1 \psi_1 + (\psi_\mathrm{target})^\ast_2 \psi_2|^2,\qquad F\in[0,1]
# \end{eqnarray}
#
# where $\ast$ stands for complex conjugation. Physically, the fidelity corresponds to the angle between the arrows representing the qubit state on the Bloch sphere (we want to maximize the fidelity but minimize the angle between the states).
#
# ### Constructing the Qubit Environment
#
# Now, let us define an episodic RL environment, which contains the laws of physics that govern the dynamics of the qubit (i.e. the application of the gate operations to the qubit state). Our RL agent will later interact with this environment to learn how to control the qubit to bring it from an initial state to a prescribed target state.
#
# We define the RL states $s=(\theta,\varphi)$ as an array containing the Bloch sphere angles of the quantum state. For each step within an episode, the agent can choose to apply one out of the actions, corresponding to the four gates $(\boldsymbol{1},U_x,U_y,U_z,U_x^\dagger,U_y^\dagger,U_z^\dagger)$. We use the instantaneous fidelity w.r.t. the target state as a reward: $r_t=F=|\langle\psi_\ast|\psi(t)\rangle|^2$:
#
# **state space:** $\mathbf{S} = \{(\theta,\varphi)|\theta\in[0,\pi],\varphi\in[0,2\pi)\}$. There are no well-defined terminal states in this task. Instead, we consider a fixed number of time steps, after which the episode terminates deterministically. The target state (i.e. the qubit state we want to prepare) is $|\psi_\mathrm{target}\rangle=(1,0)^t$: it has the Bloch sphere coordinates $s_\mathrm{target}=(0,0)$.
#
# **action space:** $\mathbf{A} = \{\boldsymbol{1},U_x,U_y,U_z,U_x^\dagger,U_y^\dagger,U_z^\dagger\}$. Actions act on RL states as follows:
# 1. if the current state is $s=(\theta,\varphi)$, we first create the quantum state $|\psi(s)\rangle$;
# 2. we apply the gate $U_a$ corresponding to action $a$ to the quantum state, and obtain the new quantum state $|\psi(s')\rangle = U_a|\psi(s)\rangle$.
# 3. last, we compute the Bloch sphere coordinates which define the next state $s'=(\theta',\varphi')$, using the Bloch sphere parametrization for qubits given above.
# Note that all actions are allowed from every state.
#
#
# **reward space:** $\mathbf{R}=[0,1]$. We use the fidelity between the next state $s'$ and the terminal state $s_\mathrm{target}$ as a reward at every episode step:
#
# $$r(s,s',a)= F = |\langle\psi_\mathrm{target}|U_a|\psi(s)\rangle|^2=|\langle\psi_\mathrm{target}|\psi(s')\rangle|^2$$
#
# for all states $s,s'\in\mathcal{S}$ and actions $a\in\mathcal{A}$.

# %%
class QubitEnv():
    """
    Gym style environment for RL. You may also inherit the class structure from OpenAI Gym. 
    Parameters:
        n_time_steps:   int
                        Total number of time steps within each episode
        seed:   int
                seed of the RNG (for reproducibility)
    """
    
    def __init__(self, n_time_steps, seed):
        """
        Initialize the environment.
        
        """
        
        self.n_time_steps = n_time_steps
        
        
        ### define action space variables
        self.delta_t = np.pi/n_time_steps # set a value for the time step
        
        # define Pauli matrices
        Id     =np.array([[1.0,0.0  ], [0.0 ,+1.0]])
        sigma_x=np.array([[0.0,1.0  ], [1.0 , 0.0]])
        sigma_y=np.array([[0.0,-1.0j], [1.0j, 0.0]])
        sigma_z=np.array([[1.0,0.0  ], [0.0 ,-1.0]])

        self.gate_generators = {'I':Id, '+X':sigma_x, '+Y':sigma_y, '+Z':sigma_z, '-X':-sigma_x, '-Y':-sigma_y, '-Z':-sigma_z}

        self.action_space=[]
        for generator in self.gate_generators.values():
            self.action_space.append( expm(-1j*self.delta_t*0.5*generator) )

        self.n_actions = len(self.action_space) # action space size
        self.actions = np.arange(self.n_actions) # action integer encoding
        
        
        ### define state space variables
        self.S_target = np.array([0.0,0.0])
        self.psi_target = self.RL_to_qubit_state(self.S_target)
        
        
        # set seed
        self.set_seed(seed)
        self.reset()
    
    
    def step(self, action):
        """
        Interface between environment and agent. Performs one step in the environemnt.
        Parameters:
            action: int
                    the index of the respective action in the action array
        Returns:
            output: ( object, float, bool)
                    information provided by the environment about its current state:
                    (state, reward, done)
        """

        # apply gate to quantum state
        self.psi = self.action_space[action].dot(self.psi)
        
        # compute RL state
        self.state = self.qubit_to_RL_state(self.psi)
        
        # compute reward
        reward = np.abs( self.psi_target.conj().dot(self.psi)  )**2
        
        # check if state is terminal
        done=False # currently obsolete, but see problem A3
        
        return self.state, reward, done

    
    def set_seed(self,seed=0):
        """
        Sets the seed of the RNG.
        """
        np.random.seed(seed)
    
    
    def reset(self, random=True):
        """
        Resets the environment to its initial values.
        Returns:
            state:  object
                    the initial state of the environment
            random: bool
                    controls whether the initial state is a random state on the sphere or a fixed initial state.
        """
        
        if random:
            theta = np.pi*np.random.uniform(0.0,1.0)
            phi = 2*np.pi*np.random.uniform(0.0,1.0)
        else:
            # start from south pole of Bloch sphere
            theta=np.pi
            phi=0.0
        
        self.state=np.array([theta,phi])
        self.psi=self.RL_to_qubit_state(self.state)

        return self.state

    
    
    def render(self):
        """
        Plots the state of the environment. For visulization purposes only. Feel free to ignore. 
        """
        pass
    
    
    def RL_to_qubit_state(self,s):
        """
        Take as input the RL state s, and return the quantum state |psi>
        """
        theta, phi = s
        psi = np.array([np.cos(0.5*theta), np.exp(1j*phi)*np.sin(0.5*theta)] )
        return psi
    
    
    def qubit_to_RL_state(self,psi):
        """
        Take as input the RL state s, and return the quantum state |psi>
        """
        # take away unphysical global phase
        alpha = np.angle(psi[0])
        psi_new = np.exp(-1j*alpha) * psi 
        
        # find Bloch sphere angles
        theta = 2.0*np.arccos(psi_new[0]).real
        phi = np.angle(psi_new[1])
        
        return np.array([theta, phi])

# %% [markdown]
# Let us test how the qubit environment works.

# %%
# set seed of rng (for reproducibility of the results)
n_time_steps = 15 # 60 # steps of each episode

# create environment and reset it to a random initial state
env=QubitEnv(n_time_steps,seed)
env.reset(random=True)

done=False
j=0
while j < n_time_steps:
    
    # pick a random action
    action=np.random.choice(env.actions) # equiprobable policy
    
    # take an environment step
    state=env.state.copy()
    next_state, reward, done = env.step(action)
    
    print("{}. s={}, a={}, r={}, s'={}\n".format(j, state, action, np.round(reward,6), next_state))
    
    j+=1
    
    if done:
        print('\nreached terminal state!')
        break
# Out:
# 0. s=[1.89 3.42], a=1, r=0.317401, s'=[ 1.94 -2.93]
#
# 1. s=[ 1.94 -2.93], a=3, r=0.317401, s'=[ 1.94 -2.72]
#
# 2. s=[ 1.94 -2.72], a=5, r=0.232923, s'=[ 2.13 -2.68]
#
# 3. s=[ 2.13 -2.68], a=2, r=0.317401, s'=[ 1.94 -2.72]
#
# 4. s=[ 1.94 -2.72], a=4, r=0.36062, s'=[ 1.85 -2.66]
#
# 5. s=[ 1.85 -2.66], a=6, r=0.36062, s'=[ 1.85 -2.87]
#
# 6. s=[ 1.85 -2.87], a=0, r=0.36062, s'=[ 1.85 -2.87]
#
# 7. s=[ 1.85 -2.87], a=0, r=0.36062, s'=[ 1.85 -2.87]
#
# 8. s=[ 1.85 -2.87], a=4, r=0.390526, s'=[ 1.79 -2.82]
#
# 9. s=[ 1.79 -2.82], a=2, r=0.489072, s'=[ 1.59 -2.83]
#
# 10. s=[ 1.59 -2.83], a=1, r=0.457013, s'=[ 1.66 -2.84]
#
# 11. s=[ 1.66 -2.84], a=6, r=0.457013, s'=[ 1.66 -3.05]
#
# 12. s=[ 1.66 -3.05], a=6, r=0.457013, s'=[1.66 3.03]
#
# 13. s=[1.66 3.03], a=0, r=0.457013, s'=[1.66 3.03]
#
# 14. s=[1.66 3.03], a=1, r=0.469702, s'=[1.63 3.01]

# %% [markdown]
# ## Policy Gradient Implementation
#
# The implementation of the PG algorithm proceeds as follows:
#
# 1. Define a SoftMax model for the discrete policy $\pi_\theta$.
# 2. Define the pseudo loss function to easily compute $\nabla_\theta J(\theta)$.
# 3. Define generalized gradient descent optimizer.
# 4. Define the PG training loop and train the policy.
#
# *Note:* if you are familiar with solving the MNIST problem, you will recognize many of the steps used to construct and train the neural network. What is different here is the training algorithm.
#
# ### Define a SoftMax model for the discrete policy $\pi_\theta$
#
# Use JAX to construct a feed-forward fully-connected deep neural network with neuron architecture $(M_s, 512, 256, |\mathcal{A}|)$, where there are $512$ ($256$) neurons in the first (second) hidden layer, respectively, and $M_s$ and $|\mathcal{A}|$ define the input and output sizes.
#
# The input data into the neural network should have the shape `input_shape = (-1, n_time_steps, M_s)`, where `M_s` is the number of features/components in the RL state $s=(\theta,\varphi)$. The output data should have the shape `output_shape = (-1, n_time_steps, abs_A)`, where `abs_A`$=|\mathcal{A}|$. In this way, we can use the neural network to process simultaneously all time steps and MC samples, generated in a single training iteration.
#
# Check explicitly the output shape and test that the network runs on some fake data (e.g. a small batch of vectors of ones with the appropriate shape).

# %%
import jax.numpy as jnp # jax's numpy version with GPU support
from jax import random # used to define a RNG key to control the random input in JAX
from jax.example_libraries import stax # neural network library
from jax.example_libraries.stax import Dense, Relu, LogSoftmax # neural network layers

# set key for the RNG (see JAX docs)
rng = random.PRNGKey(seed)

# define functions which initialize the parameters and evaluate the model
initialize_params, predict = stax.serial(
                                            ### fully connected DNN
                                            Dense(512), # 512 hidden neurons
                                            Relu,
                                            Dense(256), # 256 hidden neurons
                                            Relu,
                                            Dense(env.n_actions), # output neurons: number of gates/actions
                                            LogSoftmax # note: computes the log-probability
                                        )

# initialize the model parameters
input_shape = (-1,env.n_time_steps,2) # -1: number of MC points, number of time steps, size of state vector
output_shape, inital_params = initialize_params(rng, input_shape) # fcc layer 28x28 pixes in each image

print('\noutput shape of the policy network is {}.\n'.format(output_shape))

# test network
states=np.ones((3,env.n_time_steps,2), dtype=np.float32)

predictions = predict(inital_params, states)
# check the output shape
print(predictions.shape)
# Out:
# output shape of the policy network is (-1, 15, 7).
#
# (3, 15, 7)

# %% [markdown]
# ### Define the pseudo loss function to easily compute $\nabla_\theta J(\theta)$
#
# REINFORCE allows to define a scalar pseudoloss function, whose gradients give $\nabla_\theta J(\theta)$. Note that this pseudoloss does ***NOT*** correspond to the RL objective $J(\theta)$: the difference stems from the fact that the two operations of taking the derivative and performing the MC approximation are not interchangeable (do you see why?).
#
# $$
# J_\mathrm{pseudo}(\theta) =
# \frac{1}{N}\sum_{j=1}^N \sum_{t=1}^T \log \pi_\theta(a^j_t|s^j_t) \left[\sum_{t'=t}^T r(a^j_{t'}|s^j_{t'}) - b_t\right],\qquad
# b_t = \frac{1}{N}\sum_{j=1}^N G_t(\tau_j).
# $$
# The baseline is a sample average of the reward-to-go (return) from time step $t$ onwards: $G_t(\tau_j) = \sum_{t'=t}^N r(s^j_{t'},s^j_{t'})$ .
#
# Because we will be doing gradient **a**scent, do **NOT** forget to add an extra minus sign to the output ot the pseudoloss (or else your agent will end up minimizing the return).
#
# Below, we also add an L2 regularizer to the pseudoloss function to prevent overfitting.

# %%
### define loss and accuracy functions

from jax import grad
from jax.tree_util import tree_flatten # jax params are stored as nested tuples; use this to manipulate tuples


def l2_regularizer(params, lmbda):
    """
    Define l2 regularizer: $\lambda \ sum_j ||theta_j||^2 $ for every parameter in the model $\theta_j$
    
    """
    return lmbda*jnp.sum(jnp.array([jnp.sum(jnp.abs(theta)**2) for theta in tree_flatten(params)[0] ]))


def pseudo_loss(params, trajectory_batch):
    """
    Define the pseudo loss function for policy gradient. 
    
    params: object(jax pytree):
        parameters of the deep policy network.
    trajectory_batch: tuple (states, actions, returns) containing the RL states, actions and returns (not the rewards!): 
        states: np.array of size (N_MC, env.n_time_steps,2)
        actions: np.array of size (N_MC, env.n_time_steps)
        returns: np.array of size (N_MC, env.n_time_steps)
    
    Returns:
        -J_{pseudo}(\theta)

    """
    # extract data from the batch
    states, actions, returns = trajectory_batch
    # compute policy predictions
    preds = predict(params, states)
    # combute the baseline
    baseline = jnp.mean(returns, axis=0)
    # select those values of the policy along the action trajectory
    preds_select = jnp.take_along_axis(preds, jnp.expand_dims(actions, axis=2), axis=2).squeeze()
    # return negative pseudo loss function (want to maximize reward with gradient DEscent)
    return -jnp.mean(jnp.sum(preds_select * (returns - baseline) )) + l2_regularizer(params, 0.001)

# %% [markdown]
# ### Define generalized gradient descent optimizer
#
# Define the optimizer and the `update` function which computes the gradient o the pseudo-loss function and performs the update.
#
# We use the Adam optimizer here with `step_size = 0.001` and the rest of the parameters have default values.

# %%
### define generalized gradient descent optimizer and a function to update model parameters

from jax.example_libraries import optimizers # gradient descent optimizers
from jax import jit

step_size = 0.001 # step size or learning rate 

# compute optimizer functions
opt_init, opt_update, get_params = optimizers.adam(step_size)


# define function which updates the parameters using the change computed by the optimizer
@jit # Just In Time compilation speeds up the code; requires to use jnp everywhere; remove when debugging
def update(i, opt_state, batch):
    """
    i: int,
        counter to count how many update steps we have performed
    opt_state: object,
        the state of the optimizer
    batch: np.array
        batch containing the data used to update the model
        
    Returns: 
    opt_state: object,
        the new state of the optimizer
        
    """
    # get current parameters of the model
    current_params = get_params(opt_state)
    # compute gradients
    grad_params = grad(pseudo_loss)(current_params, batch)
    # use the optimizer to perform the update using opt_update
    return opt_update(i, grad_params, opt_state)

# %% [markdown]
# ### Define the PG training loop and train the policy
#
# Finally, we implement the REINFORCE algorithm for policy gradient. Follow the steps below:
#
# 1. Preallocate variables
#     * Define the number of episodes `N_episodes`, and the batch size `N_MC`.
#     * Preallocate arrays for the current `state`, and the `states`, `actions`, `returns` triple which defines the trajectory batch.
#     * Preallocate arrays to compute the `mean_final_reward`, `std_final_reward`, `min_final_reward`, and , `max_final_reward`.
# 2. Initialize the optimizer using the `opt_init` function.
# 3. Loop over the episodes; for every episode:
#
#     3.1 get the current Network parameters
#
#     3.2 loop to collect MC samples
#
#       3.2.1 reset the `env` and roll out the policy until the episode is over; collect the trajectory data
#
#       3.2.2 compute the returns (rewards to go)
#
#     3.3 compile the PG data into a trajectory batch
#
#     3.4 use the `update` function to update the network parameters
#
#     3.5 print instantaneous performance

# %%
### Train model

import time

# define number of training episodes
N_episodes = 401 # total number of training episodes
N_MC = 256 # # number of trajectories in the batch


# preallocate data using arrays initialized with zeros
state=np.zeros((2,), dtype=np.float32)
    
states = np.zeros((N_MC, env.n_time_steps,2), dtype=np.float32)
actions = np.zeros((N_MC, env.n_time_steps), dtype=np.int64)
returns = np.zeros((N_MC, env.n_time_steps), dtype=np.float32)
    
# mean reward at the end of the episode
mean_final_reward = np.zeros(N_episodes, dtype=np.float32)
# standard deviation of the reward at the end of the episode
std_final_reward = np.zeros_like(mean_final_reward)
# batch minimum at the end of the episode
min_final_reward = np.zeros_like(mean_final_reward)
# batch maximum at the end of the episode
max_final_reward = np.zeros_like(mean_final_reward)


print("\nStarting training...\n")

# set the initial model parameters in the optimizer
opt_state = opt_init(inital_params)

# loop over the number of training episodes
for episode in range(N_episodes): 
    
    ### record time
    start_time = time.time()
    
    # get current policy  network params
    current_params = get_params(opt_state)
    
    # MC sample
    for j in range(N_MC): # can be parallelized to collect data more efficiently!
        
        # reset environment to a random initial state
        #env.reset(random=False) # fixed initial state (cf. env)
        env.reset(random=True) # Haar-random initial state (i.e. uniformly sampled on the sphere)
    
        # zero rewards array (auxiliary array to store the rewards, and help compute the returns)
        rewards = np.zeros((env.n_time_steps, ), dtype=np.float32)
    
        # loop over steps in an episode
        for time_step in range(env.n_time_steps):

            # select state
            state[:] = env.state[:]
            states[j,time_step,:] = state

            # select an action according to current policy
            pi_s = np.exp( predict(current_params, state) )
            action = np.random.choice(env.actions, p = pi_s)
            actions[j,time_step] = action

            # take an environment step
            state[:], reward, _ = env.step(action)

            # store reward
            rewards[time_step] = reward
            
        # compute reward-to-go 
        returns[j,:] = jnp.cumsum(rewards[::-1])[::-1]
        
           
    # define batch of data
    trajectory_batch = (states, actions, returns)
    
    # update neural network model for policy
    opt_state = update(episode, opt_state, trajectory_batch)
            
    ### record time needed for a single epoch
    episode_time = time.time() - start_time
    
    # check performance
    mean_final_reward[episode]=jnp.mean(returns[:,-1])
    std_final_reward[episode] =jnp.std(returns[:,-1])
    min_final_reward[episode], max_final_reward[episode] = np.min(returns[:,-1]), np.max(returns[:,-1])

    # print results every 10 epochs
    #if episode % 5 == 0:
    print("episode {} in {:0.2f} sec".format(episode, episode_time))
    print("mean reward: {:0.4f}".format(mean_final_reward[episode]) )
    print("return standard deviation: {:0.4f}".format(std_final_reward[episode]) )
    print("min return: {:0.4f}; max return: {:0.4f}\n".format(min_final_reward[episode], max_final_reward[episode]) )
# Out:
# Starting training...
#
# episode 0 in 0.77 sec
# mean reward: 0.4917
# return standard deviation: 0.3273
# min return: 0.0007; max return: 0.9983
#
# episode 1 in 0.47 sec
# mean reward: 0.4921
# return standard deviation: 0.3174
# min return: 0.0032; max return: 0.9922
#
# episode 2 in 0.48 sec
# mean reward: 0.4998
# return standard deviation: 0.3304
# min return: 0.0011; max return: 0.9978
#
# episode 3 in 0.48 sec
# mean reward: 0.5607
# return standard deviation: 0.3185
# min return: 0.0098; max return: 0.9998
#
# episode 4 in 0.46 sec
# mean reward: 0.5261
# return standard deviation: 0.3249
# min return: 0.0000; max return: 0.9988
#
# episode 5 in 0.46 sec
# mean reward: 0.5948
# return standard deviation: 0.2938
# min return: 0.0309; max return: 0.9976
#
# episode 6 in 0.46 sec
# mean reward: 0.6404
# return standard deviation: 0.2853
# min return: 0.0055; max return: 0.9983
#
# episode 7 in 0.46 sec
# mean reward: 0.6588
# return standard deviation: 0.2909
# min return: 0.0248; max return: 1.0000
#
# episode 8 in 0.46 sec
# mean reward: 0.6566
# return standard deviation: 0.2798
# min return: 0.0137; max return: 0.9994
#
# episode 9 in 0.46 sec
# mean reward: 0.6621
# return standard deviation: 0.2713
# min return: 0.0312; max return: 0.9998
#
# episode 10 in 0.46 sec
# mean reward: 0.7292
# return standard deviation: 0.2489
# min return: 0.0310; max return: 0.9993
#
# episode 11 in 0.46 sec
# mean reward: 0.7462
# return standard deviation: 0.2348
# min return: 0.0070; max return: 0.9980
#
# episode 12 in 0.47 sec
# mean reward: 0.7478
# return standard deviation: 0.2508
# min return: 0.0332; max return: 0.9997
#
# episode 13 in 0.47 sec
# mean reward: 0.7450
# return standard deviation: 0.2598
# min return: 0.0038; max return: 0.9999
#
# episode 14 in 0.48 sec
# mean reward: 0.7818
# return standard deviation: 0.2259
# min return: 0.0845; max return: 0.9999
#
# episode 15 in 0.47 sec
# mean reward: 0.8381
# return standard deviation: 0.1845
# min return: 0.0260; max return: 0.9999
#
# episode 16 in 0.47 sec
# mean reward: 0.8231
# return standard deviation: 0.2074
# min return: 0.0170; max return: 0.9999
#
# episode 17 in 0.47 sec
# mean reward: 0.8179
# return standard deviation: 0.2200
# min return: 0.0569; max return: 1.0000
#
# episode 18 in 0.48 sec
# mean reward: 0.8274
# return standard deviation: 0.2055
# min return: 0.0709; max return: 0.9999
#
# episode 19 in 0.47 sec
# mean reward: 0.8427
# return standard deviation: 0.1885
# min return: 0.1338; max return: 0.9998
#
# episode 20 in 0.47 sec
# mean reward: 0.8347
# return standard deviation: 0.1838
# min return: 0.1836; max return: 0.9997
#
# episode 21 in 0.47 sec
# mean reward: 0.8783
# return standard deviation: 0.1517
# min return: 0.2500; max return: 0.9999
#
# episode 22 in 0.47 sec
# mean reward: 0.8709
# return standard deviation: 0.1508
# min return: 0.2198; max return: 0.9990
#
# episode 23 in 0.47 sec
# mean reward: 0.8704
# return standard deviation: 0.1552
# min return: 0.1596; max return: 0.9998
#
# episode 24 in 0.47 sec
# mean reward: 0.8767
# return standard deviation: 0.1403
# min return: 0.2416; max return: 0.9997
#
# episode 25 in 0.46 sec
# mean reward: 0.8815
# return standard deviation: 0.1414
# min return: 0.2583; max return: 0.9998
#
# episode 26 in 0.47 sec
# mean reward: 0.8836
# return standard deviation: 0.1392
# min return: 0.2888; max return: 0.9999
#
# episode 27 in 0.46 sec
# mean reward: 0.8931
# return standard deviation: 0.1295
# min return: 0.2439; max return: 1.0000
#
# episode 28 in 0.47 sec
# mean reward: 0.8854
# return standard deviation: 0.1454
# min return: 0.2117; max return: 0.9997
#
# episode 29 in 0.47 sec
# mean reward: 0.9038
# return standard deviation: 0.1153
# min return: 0.3894; max return: 0.9999
#
# episode 30 in 0.46 sec
# mean reward: 0.9171
# return standard deviation: 0.1027
# min return: 0.3401; max return: 0.9998
#
# episode 31 in 0.47 sec
# mean reward: 0.9113
# return standard deviation: 0.1006
# min return: 0.4648; max return: 0.9998
#
# episode 32 in 0.47 sec
# mean reward: 0.9113
# return standard deviation: 0.1090
# min return: 0.2462; max return: 0.9998
#
# episode 33 in 0.47 sec
# mean reward: 0.9200
# return standard deviation: 0.1131
# min return: 0.4157; max return: 0.9999
#
# episode 34 in 0.47 sec
# mean reward: 0.9208
# return standard deviation: 0.1018
# min return: 0.2813; max return: 0.9994
#
# episode 35 in 0.46 sec
# mean reward: 0.9241
# return standard deviation: 0.0986
# min return: 0.4136; max return: 0.9992
#
# episode 36 in 0.47 sec
# mean reward: 0.9158
# return standard deviation: 0.1087
# min return: 0.4098; max return: 0.9999
#
# episode 37 in 0.47 sec
# mean reward: 0.9354
# return standard deviation: 0.0835
# min return: 0.5882; max return: 0.9997
#
# episode 38 in 0.48 sec
# mean reward: 0.9275
# return standard deviation: 0.0920
# min return: 0.5361; max return: 0.9999
#
# episode 39 in 0.47 sec
# mean reward: 0.9296
# return standard deviation: 0.0899
# min return: 0.4958; max return: 0.9998
#
# episode 40 in 0.49 sec
# mean reward: 0.9365
# return standard deviation: 0.0858
# min return: 0.4855; max return: 1.0000
#
# episode 41 in 0.47 sec
# mean reward: 0.9416
# return standard deviation: 0.0793
# min return: 0.5394; max return: 1.0000
#
# episode 42 in 0.47 sec
# mean reward: 0.9359
# return standard deviation: 0.0913
# min return: 0.4757; max return: 0.9999
#
# episode 43 in 0.46 sec
# mean reward: 0.9443
# return standard deviation: 0.0813
# min return: 0.3593; max return: 0.9997
#
# episode 44 in 0.46 sec
# mean reward: 0.9461
# return standard deviation: 0.0691
# min return: 0.6626; max return: 0.9998
#
# episode 45 in 0.46 sec
# mean reward: 0.9509
# return standard deviation: 0.0677
# min return: 0.5601; max return: 0.9999
#
# episode 46 in 0.47 sec
# mean reward: 0.9548
# return standard deviation: 0.0680
# min return: 0.6021; max return: 1.0000
#
# episode 47 in 0.46 sec
# mean reward: 0.9556
# return standard deviation: 0.0587
# min return: 0.6714; max return: 1.0000
#
# episode 48 in 0.46 sec
# mean reward: 0.9520
# return standard deviation: 0.0680
# min return: 0.6264; max return: 0.9999
#
# episode 49 in 0.47 sec
# mean reward: 0.9585
# return standard deviation: 0.0708
# min return: 0.5888; max return: 0.9999
#
# episode 50 in 0.47 sec
# mean reward: 0.9605
# return standard deviation: 0.0626
# min return: 0.6065; max return: 1.0000
#
# episode 51 in 0.48 sec
# mean reward: 0.9561
# return standard deviation: 0.0605
# min return: 0.6905; max return: 0.9997
#
# episode 52 in 0.47 sec
# mean reward: 0.9649
# return standard deviation: 0.0554
# min return: 0.5372; max return: 1.0000
#
# episode 53 in 0.47 sec
# mean reward: 0.9583
# return standard deviation: 0.0647
# min return: 0.4258; max return: 0.9997
#
# episode 54 in 0.47 sec
# mean reward: 0.9620
# return standard deviation: 0.0645
# min return: 0.3613; max return: 0.9998
#
# episode 55 in 0.47 sec
# mean reward: 0.9648
# return standard deviation: 0.0506
# min return: 0.7210; max return: 1.0000
#
# episode 56 in 0.47 sec
# mean reward: 0.9635
# return standard deviation: 0.0604
# min return: 0.6385; max return: 0.9999
#
# episode 57 in 0.48 sec
# mean reward: 0.9710
# return standard deviation: 0.0459
# min return: 0.6246; max return: 1.0000
#
# episode 58 in 0.47 sec
# mean reward: 0.9656
# return standard deviation: 0.0564
# min return: 0.5870; max return: 1.0000
#
# episode 59 in 0.47 sec
# mean reward: 0.9647
# return standard deviation: 0.0552
# min return: 0.6168; max return: 1.0000
#
# episode 60 in 0.47 sec
# mean reward: 0.9687
# return standard deviation: 0.0519
# min return: 0.6300; max return: 1.0000
#
# episode 61 in 0.48 sec
# mean reward: 0.9679
# return standard deviation: 0.0525
# min return: 0.5309; max return: 1.0000
#
# episode 62 in 0.46 sec
# mean reward: 0.9687
# return standard deviation: 0.0520
# min return: 0.6582; max return: 1.0000
#
# episode 63 in 0.47 sec
# mean reward: 0.9678
# return standard deviation: 0.0449
# min return: 0.7206; max return: 0.9998
#
# episode 64 in 0.48 sec
# mean reward: 0.9608
# return standard deviation: 0.0557
# min return: 0.7146; max return: 1.0000
#
# episode 65 in 0.47 sec
# mean reward: 0.9704
# return standard deviation: 0.0477
# min return: 0.6696; max return: 1.0000
#
# episode 66 in 0.47 sec
# mean reward: 0.9688
# return standard deviation: 0.0467
# min return: 0.6985; max return: 0.9999
#
# episode 67 in 0.50 sec
# mean reward: 0.9716
# return standard deviation: 0.0461
# min return: 0.7687; max return: 0.9999
#
# episode 68 in 0.49 sec
# mean reward: 0.9696
# return standard deviation: 0.0441
# min return: 0.7055; max return: 0.9999
#
# episode 69 in 0.47 sec
# mean reward: 0.9699
# return standard deviation: 0.0498
# min return: 0.6124; max return: 1.0000
#
# episode 70 in 0.47 sec
# mean reward: 0.9737
# return standard deviation: 0.0458
# min return: 0.6325; max return: 0.9999
#
# episode 71 in 0.47 sec
# mean reward: 0.9737
# return standard deviation: 0.0388
# min return: 0.6860; max return: 0.9999
#
# episode 72 in 0.48 sec
# mean reward: 0.9731
# return standard deviation: 0.0445
# min return: 0.6446; max return: 1.0000
#
# episode 73 in 0.46 sec
# mean reward: 0.9763
# return standard deviation: 0.0391
# min return: 0.7020; max return: 1.0000
#
# episode 74 in 0.47 sec
# mean reward: 0.9766
# return standard deviation: 0.0345
# min return: 0.7942; max return: 0.9998
#
# episode 75 in 0.47 sec
# mean reward: 0.9679
# return standard deviation: 0.0606
# min return: 0.6048; max return: 1.0000
#
# episode 76 in 0.47 sec
# mean reward: 0.9787
# return standard deviation: 0.0396
# min return: 0.6886; max return: 0.9999
#
# episode 77 in 0.46 sec
# mean reward: 0.9778
# return standard deviation: 0.0368
# min return: 0.7067; max return: 0.9999
#
# episode 78 in 0.49 sec
# mean reward: 0.9793
# return standard deviation: 0.0364
# min return: 0.5617; max return: 1.0000
#
# episode 79 in 0.48 sec
# mean reward: 0.9781
# return standard deviation: 0.0363
# min return: 0.7167; max return: 0.9999
#
# episode 80 in 0.48 sec
# mean reward: 0.9777
# return standard deviation: 0.0420
# min return: 0.6647; max return: 1.0000
#
# episode 81 in 0.47 sec
# mean reward: 0.9785
# return standard deviation: 0.0320
# min return: 0.7737; max return: 0.9999
#
# episode 82 in 0.48 sec
# mean reward: 0.9812
# return standard deviation: 0.0283
# min return: 0.7864; max return: 1.0000
#
# episode 83 in 0.47 sec
# mean reward: 0.9819
# return standard deviation: 0.0351
# min return: 0.6942; max return: 1.0000
#
# episode 84 in 0.47 sec
# mean reward: 0.9843
# return standard deviation: 0.0201
# min return: 0.8054; max return: 1.0000
#
# episode 85 in 0.47 sec
# mean reward: 0.9758
# return standard deviation: 0.0415
# min return: 0.6638; max return: 0.9999
#
# episode 86 in 0.47 sec
# mean reward: 0.9785
# return standard deviation: 0.0393
# min return: 0.6512; max return: 0.9999
#
# episode 87 in 0.46 sec
# mean reward: 0.9815
# return standard deviation: 0.0304
# min return: 0.7508; max return: 1.0000
#
# episode 88 in 0.47 sec
# mean reward: 0.9821
# return standard deviation: 0.0242
# min return: 0.8435; max return: 1.0000
#
# episode 89 in 0.46 sec
# mean reward: 0.9813
# return standard deviation: 0.0328
# min return: 0.7283; max return: 1.0000
#
# episode 90 in 0.47 sec
# mean reward: 0.9791
# return standard deviation: 0.0375
# min return: 0.5573; max return: 0.9999
#
# episode 91 in 0.47 sec
# mean reward: 0.9800
# return standard deviation: 0.0278
# min return: 0.8528; max return: 0.9999
#
# episode 92 in 0.47 sec
# mean reward: 0.9737
# return standard deviation: 0.0478
# min return: 0.5991; max return: 1.0000
#
# episode 93 in 0.48 sec
# mean reward: 0.9773
# return standard deviation: 0.0445
# min return: 0.6320; max return: 0.9999
#
# episode 94 in 0.46 sec
# mean reward: 0.9793
# return standard deviation: 0.0286
# min return: 0.8260; max return: 1.0000
#
# episode 95 in 0.47 sec
# mean reward: 0.9795
# return standard deviation: 0.0388
# min return: 0.6363; max return: 1.0000
#
# episode 96 in 0.47 sec
# mean reward: 0.9838
# return standard deviation: 0.0245
# min return: 0.8117; max return: 1.0000
#
# episode 97 in 0.47 sec
# mean reward: 0.9808
# return standard deviation: 0.0402
# min return: 0.6825; max return: 1.0000
#
# episode 98 in 0.50 sec
# mean reward: 0.9844
# return standard deviation: 0.0274
# min return: 0.7865; max return: 1.0000
#
# episode 99 in 0.53 sec
# mean reward: 0.9837
# return standard deviation: 0.0249
# min return: 0.8031; max return: 1.0000
#
# episode 100 in 0.47 sec
# mean reward: 0.9855
# return standard deviation: 0.0266
# min return: 0.7406; max return: 1.0000
#
# episode 101 in 0.48 sec
# mean reward: 0.9824
# return standard deviation: 0.0365
# min return: 0.6320; max return: 0.9999
#
# episode 102 in 0.53 sec
# mean reward: 0.9834
# return standard deviation: 0.0337
# min return: 0.6161; max return: 1.0000
#
# episode 103 in 0.47 sec
# mean reward: 0.9849
# return standard deviation: 0.0250
# min return: 0.7512; max return: 0.9999
#
# episode 104 in 0.49 sec
# mean reward: 0.9824
# return standard deviation: 0.0340
# min return: 0.7361; max return: 1.0000
#
# episode 105 in 0.49 sec
# mean reward: 0.9852
# return standard deviation: 0.0317
# min return: 0.6766; max return: 1.0000
#
# episode 106 in 0.48 sec
# mean reward: 0.9864
# return standard deviation: 0.0202
# min return: 0.8387; max return: 1.0000
#
# episode 107 in 0.48 sec
# mean reward: 0.9864
# return standard deviation: 0.0264
# min return: 0.7218; max return: 1.0000
#
# episode 108 in 0.47 sec
# mean reward: 0.9825
# return standard deviation: 0.0389
# min return: 0.5873; max return: 1.0000
#
# episode 109 in 0.47 sec
# mean reward: 0.9881
# return standard deviation: 0.0214
# min return: 0.7909; max return: 1.0000
#
# episode 110 in 0.47 sec
# mean reward: 0.9885
# return standard deviation: 0.0251
# min return: 0.7046; max return: 1.0000
#
# episode 111 in 0.47 sec
# mean reward: 0.9863
# return standard deviation: 0.0227
# min return: 0.8059; max return: 1.0000
#
# episode 112 in 0.47 sec
# mean reward: 0.9858
# return standard deviation: 0.0236
# min return: 0.8089; max return: 0.9999
#
# episode 113 in 0.47 sec
# mean reward: 0.9838
# return standard deviation: 0.0359
# min return: 0.7051; max return: 1.0000
#
# episode 114 in 0.47 sec
# mean reward: 0.9854
# return standard deviation: 0.0327
# min return: 0.6373; max return: 1.0000
#
# episode 115 in 0.47 sec
# mean reward: 0.9852
# return standard deviation: 0.0289
# min return: 0.7520; max return: 1.0000
#
# episode 116 in 0.47 sec
# mean reward: 0.9813
# return standard deviation: 0.0380
# min return: 0.6738; max return: 1.0000
#
# episode 117 in 0.47 sec
# mean reward: 0.9796
# return standard deviation: 0.0456
# min return: 0.5125; max return: 1.0000
#
# episode 118 in 0.49 sec
# mean reward: 0.9832
# return standard deviation: 0.0311
# min return: 0.7779; max return: 1.0000
#
# episode 119 in 0.47 sec
# mean reward: 0.9802
# return standard deviation: 0.0358
# min return: 0.6694; max return: 0.9999
#
# episode 120 in 0.47 sec
# mean reward: 0.9802
# return standard deviation: 0.0337
# min return: 0.7132; max return: 1.0000
#
# episode 121 in 0.47 sec
# mean reward: 0.9811
# return standard deviation: 0.0323
# min return: 0.7577; max return: 1.0000
#
# episode 122 in 0.47 sec
# mean reward: 0.9785
# return standard deviation: 0.0435
# min return: 0.6319; max return: 1.0000
#
# episode 123 in 0.47 sec
# mean reward: 0.9870
# return standard deviation: 0.0163
# min return: 0.8611; max return: 1.0000
#
# episode 124 in 0.47 sec
# mean reward: 0.9794
# return standard deviation: 0.0361
# min return: 0.6935; max return: 1.0000
#
# episode 125 in 0.49 sec
# mean reward: 0.9826
# return standard deviation: 0.0361
# min return: 0.6915; max return: 0.9999
#
# episode 126 in 0.54 sec
# mean reward: 0.9827
# return standard deviation: 0.0314
# min return: 0.6973; max return: 1.0000
#
# episode 127 in 0.51 sec
# mean reward: 0.9846
# return standard deviation: 0.0272
# min return: 0.7658; max return: 1.0000
#
# episode 128 in 0.51 sec
# mean reward: 0.9833
# return standard deviation: 0.0327
# min return: 0.7410; max return: 1.0000
#
# episode 129 in 0.52 sec
# mean reward: 0.9864
# return standard deviation: 0.0214
# min return: 0.8141; max return: 1.0000
#
# episode 130 in 0.49 sec
# mean reward: 0.9882
# return standard deviation: 0.0242
# min return: 0.6889; max return: 0.9999
#
# episode 131 in 0.47 sec
# mean reward: 0.9878
# return standard deviation: 0.0210
# min return: 0.7897; max return: 1.0000
#
# episode 132 in 0.47 sec
# mean reward: 0.9866
# return standard deviation: 0.0194
# min return: 0.8592; max return: 0.9999
#
# episode 133 in 0.47 sec
# mean reward: 0.9876
# return standard deviation: 0.0261
# min return: 0.6911; max return: 1.0000
#
# episode 134 in 0.47 sec
# mean reward: 0.9843
# return standard deviation: 0.0310
# min return: 0.7593; max return: 1.0000
#
# episode 135 in 0.47 sec
# mean reward: 0.9872
# return standard deviation: 0.0298
# min return: 0.6996; max return: 1.0000
#
# episode 136 in 0.49 sec
# mean reward: 0.9892
# return standard deviation: 0.0195
# min return: 0.7977; max return: 1.0000
#
# episode 137 in 0.47 sec
# mean reward: 0.9903
# return standard deviation: 0.0153
# min return: 0.8408; max return: 1.0000
#
# episode 138 in 0.48 sec
# mean reward: 0.9890
# return standard deviation: 0.0328
# min return: 0.5386; max return: 0.9999
#
# episode 139 in 0.48 sec
# mean reward: 0.9879
# return standard deviation: 0.0286
# min return: 0.6931; max return: 1.0000
#
# episode 140 in 0.47 sec
# mean reward: 0.9867
# return standard deviation: 0.0306
# min return: 0.7567; max return: 1.0000
#
# episode 141 in 0.47 sec
# mean reward: 0.9888
# return standard deviation: 0.0316
# min return: 0.5969; max return: 1.0000
#
# episode 142 in 0.47 sec
# mean reward: 0.9868
# return standard deviation: 0.0365
# min return: 0.6399; max return: 1.0000
#
# episode 143 in 0.48 sec
# mean reward: 0.9920
# return standard deviation: 0.0096
# min return: 0.9387; max return: 1.0000
#
# episode 144 in 0.48 sec
# mean reward: 0.9900
# return standard deviation: 0.0198
# min return: 0.8149; max return: 1.0000
#
# episode 145 in 0.48 sec
# mean reward: 0.9894
# return standard deviation: 0.0177
# min return: 0.8385; max return: 1.0000
#
# episode 146 in 0.48 sec
# mean reward: 0.9877
# return standard deviation: 0.0336
# min return: 0.5249; max return: 1.0000
#
# episode 147 in 0.48 sec
# mean reward: 0.9893
# return standard deviation: 0.0169
# min return: 0.8411; max return: 0.9999
#
# episode 148 in 0.48 sec
# mean reward: 0.9850
# return standard deviation: 0.0383
# min return: 0.6297; max return: 0.9999
#
# episode 149 in 0.47 sec
# mean reward: 0.9860
# return standard deviation: 0.0362
# min return: 0.5420; max return: 1.0000
#
# episode 150 in 0.48 sec
# mean reward: 0.9879
# return standard deviation: 0.0234
# min return: 0.7833; max return: 1.0000
#
# episode 151 in 0.47 sec
# mean reward: 0.9875
# return standard deviation: 0.0207
# min return: 0.8321; max return: 1.0000
#
# episode 152 in 0.47 sec
# mean reward: 0.9889
# return standard deviation: 0.0171
# min return: 0.8611; max return: 1.0000
#
# episode 153 in 0.47 sec
# mean reward: 0.9841
# return standard deviation: 0.0354
# min return: 0.6212; max return: 0.9999
#
# episode 154 in 0.47 sec
# mean reward: 0.9885
# return standard deviation: 0.0183
# min return: 0.8333; max return: 0.9999
#
# episode 155 in 0.47 sec
# mean reward: 0.9878
# return standard deviation: 0.0184
# min return: 0.8272; max return: 1.0000
#
# episode 156 in 0.47 sec
# mean reward: 0.9863
# return standard deviation: 0.0270
# min return: 0.7353; max return: 0.9999
#
# episode 157 in 0.47 sec
# mean reward: 0.9836
# return standard deviation: 0.0418
# min return: 0.5706; max return: 1.0000
#
# episode 158 in 0.47 sec
# mean reward: 0.9877
# return standard deviation: 0.0214
# min return: 0.8122; max return: 1.0000
#
# episode 159 in 0.46 sec
# mean reward: 0.9864
# return standard deviation: 0.0290
# min return: 0.7366; max return: 1.0000
#
# episode 160 in 0.47 sec
# mean reward: 0.9854
# return standard deviation: 0.0296
# min return: 0.7231; max return: 0.9999
#
# episode 161 in 0.46 sec
# mean reward: 0.9860
# return standard deviation: 0.0322
# min return: 0.6801; max return: 1.0000
#
# episode 162 in 0.46 sec
# mean reward: 0.9873
# return standard deviation: 0.0254
# min return: 0.7208; max return: 1.0000
#
# episode 163 in 0.48 sec
# mean reward: 0.9838
# return standard deviation: 0.0429
# min return: 0.6302; max return: 1.0000
#
# episode 164 in 0.47 sec
# mean reward: 0.9868
# return standard deviation: 0.0338
# min return: 0.6573; max return: 1.0000
#
# episode 165 in 0.48 sec
# mean reward: 0.9858
# return standard deviation: 0.0330
# min return: 0.7143; max return: 1.0000
#
# episode 166 in 0.47 sec
# mean reward: 0.9879
# return standard deviation: 0.0306
# min return: 0.6856; max return: 1.0000
#
# episode 167 in 0.47 sec
# mean reward: 0.9890
# return standard deviation: 0.0247
# min return: 0.6864; max return: 1.0000
#
# episode 168 in 0.47 sec
# mean reward: 0.9901
# return standard deviation: 0.0145
# min return: 0.8679; max return: 1.0000
#
# episode 169 in 0.47 sec
# mean reward: 0.9912
# return standard deviation: 0.0123
# min return: 0.9006; max return: 1.0000
#
# episode 170 in 0.47 sec
# mean reward: 0.9912
# return standard deviation: 0.0160
# min return: 0.8099; max return: 1.0000
#
# episode 171 in 0.47 sec
# mean reward: 0.9860
# return standard deviation: 0.0394
# min return: 0.6535; max return: 1.0000
#
# episode 172 in 0.47 sec
# mean reward: 0.9904
# return standard deviation: 0.0178
# min return: 0.7898; max return: 1.0000
#
# episode 173 in 0.47 sec
# mean reward: 0.9906
# return standard deviation: 0.0129
# min return: 0.9176; max return: 1.0000
#
# episode 174 in 0.47 sec
# mean reward: 0.9872
# return standard deviation: 0.0387
# min return: 0.6017; max return: 1.0000
#
# episode 175 in 0.46 sec
# mean reward: 0.9868
# return standard deviation: 0.0317
# min return: 0.6936; max return: 0.9999
#
# episode 176 in 0.47 sec
# mean reward: 0.9830
# return standard deviation: 0.0419
# min return: 0.6456; max return: 1.0000
#
# episode 177 in 0.46 sec
# mean reward: 0.9876
# return standard deviation: 0.0290
# min return: 0.7016; max return: 1.0000
#
# episode 178 in 0.47 sec
# mean reward: 0.9897
# return standard deviation: 0.0150
# min return: 0.8774; max return: 1.0000
#
# episode 179 in 0.47 sec
# mean reward: 0.9885
# return standard deviation: 0.0219
# min return: 0.7968; max return: 1.0000
#
# episode 180 in 0.47 sec
# mean reward: 0.9875
# return standard deviation: 0.0244
# min return: 0.7108; max return: 0.9998
#
# episode 181 in 0.47 sec
# mean reward: 0.9888
# return standard deviation: 0.0185
# min return: 0.8259; max return: 1.0000
#
# episode 182 in 0.47 sec
# mean reward: 0.9855
# return standard deviation: 0.0338
# min return: 0.7007; max return: 0.9999
#
# episode 183 in 0.46 sec
# mean reward: 0.9849
# return standard deviation: 0.0280
# min return: 0.7558; max return: 1.0000
#
# episode 184 in 0.46 sec
# mean reward: 0.9858
# return standard deviation: 0.0356
# min return: 0.7024; max return: 1.0000
#
# episode 185 in 0.46 sec
# mean reward: 0.9863
# return standard deviation: 0.0258
# min return: 0.7793; max return: 1.0000
#
# episode 186 in 0.47 sec
# mean reward: 0.9888
# return standard deviation: 0.0260
# min return: 0.7788; max return: 1.0000
#
# episode 187 in 0.47 sec
# mean reward: 0.9864
# return standard deviation: 0.0381
# min return: 0.6646; max return: 0.9999
#
# episode 188 in 0.47 sec
# mean reward: 0.9890
# return standard deviation: 0.0209
# min return: 0.7579; max return: 1.0000
#
# episode 189 in 0.46 sec
# mean reward: 0.9868
# return standard deviation: 0.0251
# min return: 0.8254; max return: 1.0000
#
# episode 190 in 0.46 sec
# mean reward: 0.9869
# return standard deviation: 0.0318
# min return: 0.6592; max return: 1.0000
#
# episode 191 in 0.46 sec
# mean reward: 0.9873
# return standard deviation: 0.0341
# min return: 0.6528; max return: 0.9999
#
# episode 192 in 0.47 sec
# mean reward: 0.9897
# return standard deviation: 0.0250
# min return: 0.7148; max return: 1.0000
#
# episode 193 in 0.46 sec
# mean reward: 0.9872
# return standard deviation: 0.0239
# min return: 0.8370; max return: 1.0000
#
# episode 194 in 0.47 sec
# mean reward: 0.9888
# return standard deviation: 0.0320
# min return: 0.6713; max return: 1.0000
#
# episode 195 in 0.47 sec
# mean reward: 0.9899
# return standard deviation: 0.0217
# min return: 0.7822; max return: 1.0000
#
# episode 196 in 0.48 sec
# mean reward: 0.9897
# return standard deviation: 0.0299
# min return: 0.6025; max return: 1.0000
#
# episode 197 in 0.47 sec
# mean reward: 0.9895
# return standard deviation: 0.0324
# min return: 0.5602; max return: 1.0000
#
# episode 198 in 0.46 sec
# mean reward: 0.9860
# return standard deviation: 0.0352
# min return: 0.6891; max return: 1.0000
#
# episode 199 in 0.47 sec
# mean reward: 0.9898
# return standard deviation: 0.0195
# min return: 0.8154; max return: 0.9999
#
# episode 200 in 0.47 sec
# mean reward: 0.9898
# return standard deviation: 0.0229
# min return: 0.7771; max return: 1.0000
#
# episode 201 in 0.47 sec
# mean reward: 0.9926
# return standard deviation: 0.0100
# min return: 0.9089; max return: 1.0000
#
# episode 202 in 0.47 sec
# mean reward: 0.9902
# return standard deviation: 0.0239
# min return: 0.7256; max return: 1.0000
#
# episode 203 in 0.47 sec
# mean reward: 0.9890
# return standard deviation: 0.0253
# min return: 0.7820; max return: 1.0000
#
# episode 204 in 0.47 sec
# mean reward: 0.9895
# return standard deviation: 0.0284
# min return: 0.7005; max return: 1.0000
#
# episode 205 in 0.47 sec
# mean reward: 0.9875
# return standard deviation: 0.0308
# min return: 0.6332; max return: 1.0000
#
# episode 206 in 0.46 sec
# mean reward: 0.9882
# return standard deviation: 0.0313
# min return: 0.7039; max return: 1.0000
#
# episode 207 in 0.47 sec
# mean reward: 0.9877
# return standard deviation: 0.0390
# min return: 0.5208; max return: 1.0000
#
# episode 208 in 0.49 sec
# mean reward: 0.9909
# return standard deviation: 0.0164
# min return: 0.8765; max return: 1.0000
#
# episode 209 in 0.47 sec
# mean reward: 0.9895
# return standard deviation: 0.0226
# min return: 0.7811; max return: 1.0000
#
# episode 210 in 0.47 sec
# mean reward: 0.9858
# return standard deviation: 0.0404
# min return: 0.5535; max return: 1.0000
#
# episode 211 in 0.48 sec
# mean reward: 0.9883
# return standard deviation: 0.0278
# min return: 0.7017; max return: 1.0000
#
# episode 212 in 0.47 sec
# mean reward: 0.9916
# return standard deviation: 0.0153
# min return: 0.8732; max return: 1.0000
#
# episode 213 in 0.49 sec
# mean reward: 0.9897
# return standard deviation: 0.0203
# min return: 0.8541; max return: 1.0000
#
# episode 214 in 0.53 sec
# mean reward: 0.9909
# return standard deviation: 0.0177
# min return: 0.8308; max return: 1.0000
#
# episode 215 in 0.49 sec
# mean reward: 0.9880
# return standard deviation: 0.0307
# min return: 0.6971; max return: 0.9999
#
# episode 216 in 0.47 sec
# mean reward: 0.9873
# return standard deviation: 0.0410
# min return: 0.5685; max return: 0.9999
#
# episode 217 in 0.47 sec
# mean reward: 0.9914
# return standard deviation: 0.0171
# min return: 0.8072; max return: 1.0000
#
# episode 218 in 0.47 sec
# mean reward: 0.9901
# return standard deviation: 0.0209
# min return: 0.7673; max return: 1.0000
#
# episode 219 in 0.47 sec
# mean reward: 0.9906
# return standard deviation: 0.0202
# min return: 0.7988; max return: 1.0000
#
# episode 220 in 0.48 sec
# mean reward: 0.9853
# return standard deviation: 0.0385
# min return: 0.5891; max return: 1.0000
#
# episode 221 in 0.47 sec
# mean reward: 0.9881
# return standard deviation: 0.0285
# min return: 0.7482; max return: 1.0000
#
# episode 222 in 0.48 sec
# mean reward: 0.9889
# return standard deviation: 0.0264
# min return: 0.7197; max return: 1.0000
#
# episode 223 in 0.48 sec
# mean reward: 0.9881
# return standard deviation: 0.0310
# min return: 0.6557; max return: 0.9999
#
# episode 224 in 0.48 sec
# mean reward: 0.9913
# return standard deviation: 0.0139
# min return: 0.8770; max return: 1.0000
#
# episode 225 in 0.48 sec
# mean reward: 0.9856
# return standard deviation: 0.0340
# min return: 0.6395; max return: 0.9999
#
# episode 226 in 0.49 sec
# mean reward: 0.9817
# return standard deviation: 0.0543
# min return: 0.5511; max return: 0.9999
#
# episode 227 in 0.48 sec
# mean reward: 0.9893
# return standard deviation: 0.0230
# min return: 0.7895; max return: 1.0000
#
# episode 228 in 0.48 sec
# mean reward: 0.9903
# return standard deviation: 0.0164
# min return: 0.8527; max return: 1.0000
#
# episode 229 in 0.49 sec
# mean reward: 0.9886
# return standard deviation: 0.0361
# min return: 0.5397; max return: 0.9999
#
# episode 230 in 0.50 sec
# mean reward: 0.9894
# return standard deviation: 0.0200
# min return: 0.8564; max return: 1.0000
#
# episode 231 in 0.49 sec
# mean reward: 0.9872
# return standard deviation: 0.0327
# min return: 0.6688; max return: 1.0000
#
# episode 232 in 0.49 sec
# mean reward: 0.9884
# return standard deviation: 0.0304
# min return: 0.6576; max return: 1.0000
#
# episode 233 in 0.47 sec
# mean reward: 0.9879
# return standard deviation: 0.0338
# min return: 0.6399; max return: 1.0000
#
# episode 234 in 0.49 sec
# mean reward: 0.9886
# return standard deviation: 0.0388
# min return: 0.6297; max return: 1.0000
#
# episode 235 in 0.48 sec
# mean reward: 0.9912
# return standard deviation: 0.0191
# min return: 0.7754; max return: 1.0000
#
# episode 236 in 0.48 sec
# mean reward: 0.9879
# return standard deviation: 0.0310
# min return: 0.7319; max return: 1.0000
#
# episode 237 in 0.49 sec
# mean reward: 0.9897
# return standard deviation: 0.0260
# min return: 0.6650; max return: 1.0000
#
# episode 238 in 0.48 sec
# mean reward: 0.9864
# return standard deviation: 0.0435
# min return: 0.5413; max return: 1.0000
#
# episode 239 in 0.48 sec
# mean reward: 0.9891
# return standard deviation: 0.0261
# min return: 0.7353; max return: 1.0000
#
# episode 240 in 0.49 sec
# mean reward: 0.9908
# return standard deviation: 0.0273
# min return: 0.6654; max return: 1.0000
#
# episode 241 in 0.49 sec
# mean reward: 0.9900
# return standard deviation: 0.0362
# min return: 0.5848; max return: 1.0000
#
# episode 242 in 0.48 sec
# mean reward: 0.9923
# return standard deviation: 0.0151
# min return: 0.8660; max return: 1.0000
#
# episode 243 in 0.48 sec
# mean reward: 0.9903
# return standard deviation: 0.0217
# min return: 0.7832; max return: 1.0000
#
# episode 244 in 0.49 sec
# mean reward: 0.9868
# return standard deviation: 0.0435
# min return: 0.5401; max return: 1.0000
#
# episode 245 in 0.48 sec
# mean reward: 0.9908
# return standard deviation: 0.0265
# min return: 0.7512; max return: 1.0000
#
# episode 246 in 0.49 sec
# mean reward: 0.9888
# return standard deviation: 0.0361
# min return: 0.6563; max return: 1.0000
#
# episode 247 in 0.48 sec
# mean reward: 0.9919
# return standard deviation: 0.0237
# min return: 0.7023; max return: 0.9999
#
# episode 248 in 0.49 sec
# mean reward: 0.9876
# return standard deviation: 0.0400
# min return: 0.5682; max return: 1.0000
#
# episode 249 in 0.48 sec
# mean reward: 0.9891
# return standard deviation: 0.0313
# min return: 0.6700; max return: 1.0000
#
# episode 250 in 0.48 sec
# mean reward: 0.9900
# return standard deviation: 0.0291
# min return: 0.7254; max return: 1.0000
#
# episode 251 in 0.47 sec
# mean reward: 0.9897
# return standard deviation: 0.0264
# min return: 0.7235; max return: 1.0000
#
# episode 252 in 0.48 sec
# mean reward: 0.9871
# return standard deviation: 0.0396
# min return: 0.5882; max return: 0.9999
#
# episode 253 in 0.47 sec
# mean reward: 0.9917
# return standard deviation: 0.0151
# min return: 0.8351; max return: 1.0000
#
# episode 254 in 0.48 sec
# mean reward: 0.9890
# return standard deviation: 0.0308
# min return: 0.6025; max return: 0.9999
#
# episode 255 in 0.47 sec
# mean reward: 0.9879
# return standard deviation: 0.0330
# min return: 0.7386; max return: 0.9999
#
# episode 256 in 0.47 sec
# mean reward: 0.9882
# return standard deviation: 0.0296
# min return: 0.7438; max return: 1.0000
#
# episode 257 in 0.47 sec
# mean reward: 0.9908
# return standard deviation: 0.0193
# min return: 0.8031; max return: 1.0000
#
# episode 258 in 0.47 sec
# mean reward: 0.9899
# return standard deviation: 0.0341
# min return: 0.5521; max return: 1.0000
#
# episode 259 in 0.47 sec
# mean reward: 0.9884
# return standard deviation: 0.0330
# min return: 0.6134; max return: 1.0000
#
# episode 260 in 0.46 sec
# mean reward: 0.9903
# return standard deviation: 0.0233
# min return: 0.7728; max return: 1.0000
#
# episode 261 in 0.47 sec
# mean reward: 0.9899
# return standard deviation: 0.0255
# min return: 0.6568; max return: 1.0000
#
# episode 262 in 0.47 sec
# mean reward: 0.9913
# return standard deviation: 0.0143
# min return: 0.8425; max return: 1.0000
#
# episode 263 in 0.49 sec
# mean reward: 0.9884
# return standard deviation: 0.0300
# min return: 0.6934; max return: 1.0000
#
# episode 264 in 0.47 sec
# mean reward: 0.9893
# return standard deviation: 0.0282
# min return: 0.7376; max return: 1.0000
#
# episode 265 in 0.49 sec
# mean reward: 0.9882
# return standard deviation: 0.0259
# min return: 0.8099; max return: 1.0000
#
# episode 266 in 0.47 sec
# mean reward: 0.9893
# return standard deviation: 0.0296
# min return: 0.6807; max return: 0.9999
#
# episode 267 in 0.46 sec
# mean reward: 0.9915
# return standard deviation: 0.0189
# min return: 0.8038; max return: 0.9999
#
# episode 268 in 0.49 sec
# mean reward: 0.9894
# return standard deviation: 0.0284
# min return: 0.6744; max return: 1.0000
#
# episode 269 in 0.49 sec
# mean reward: 0.9904
# return standard deviation: 0.0225
# min return: 0.7759; max return: 1.0000
#
# episode 270 in 0.47 sec
# mean reward: 0.9888
# return standard deviation: 0.0347
# min return: 0.6206; max return: 1.0000
#
# episode 271 in 0.47 sec
# mean reward: 0.9878
# return standard deviation: 0.0328
# min return: 0.6668; max return: 1.0000
#
# episode 272 in 0.46 sec
# mean reward: 0.9850
# return standard deviation: 0.0399
# min return: 0.6182; max return: 1.0000
#
# episode 273 in 0.47 sec
# mean reward: 0.9904
# return standard deviation: 0.0329
# min return: 0.5191; max return: 1.0000
#
# episode 274 in 0.47 sec
# mean reward: 0.9913
# return standard deviation: 0.0248
# min return: 0.6634; max return: 1.0000
#
# episode 275 in 0.47 sec
# mean reward: 0.9893
# return standard deviation: 0.0274
# min return: 0.7297; max return: 1.0000
#
# episode 276 in 0.47 sec
# mean reward: 0.9924
# return standard deviation: 0.0178
# min return: 0.7972; max return: 1.0000
#
# episode 277 in 0.47 sec
# mean reward: 0.9885
# return standard deviation: 0.0329
# min return: 0.6958; max return: 1.0000
#
# episode 278 in 0.47 sec
# mean reward: 0.9928
# return standard deviation: 0.0124
# min return: 0.8670; max return: 1.0000
#
# episode 279 in 0.46 sec
# mean reward: 0.9894
# return standard deviation: 0.0274
# min return: 0.7160; max return: 1.0000
#
# episode 280 in 0.47 sec
# mean reward: 0.9880
# return standard deviation: 0.0328
# min return: 0.6708; max return: 1.0000
#
# episode 281 in 0.48 sec
# mean reward: 0.9912
# return standard deviation: 0.0190
# min return: 0.8161; max return: 1.0000
#
# episode 282 in 0.48 sec
# mean reward: 0.9906
# return standard deviation: 0.0264
# min return: 0.7381; max return: 0.9999
#
# episode 283 in 0.48 sec
# mean reward: 0.9878
# return standard deviation: 0.0337
# min return: 0.6404; max return: 1.0000
#
# episode 284 in 0.49 sec
# mean reward: 0.9846
# return standard deviation: 0.0441
# min return: 0.5210; max return: 0.9999
#
# episode 285 in 0.48 sec
# mean reward: 0.9842
# return standard deviation: 0.0441
# min return: 0.5668; max return: 0.9999
#
# episode 286 in 0.48 sec
# mean reward: 0.9859
# return standard deviation: 0.0424
# min return: 0.6022; max return: 1.0000
#
# episode 287 in 0.47 sec
# mean reward: 0.9869
# return standard deviation: 0.0422
# min return: 0.5731; max return: 1.0000
#
# episode 288 in 0.47 sec
# mean reward: 0.9880
# return standard deviation: 0.0264
# min return: 0.7670; max return: 1.0000
#
# episode 289 in 0.47 sec
# mean reward: 0.9880
# return standard deviation: 0.0340
# min return: 0.6514; max return: 1.0000
#
# episode 290 in 0.48 sec
# mean reward: 0.9894
# return standard deviation: 0.0242
# min return: 0.6943; max return: 0.9999
#
# episode 291 in 0.48 sec
# mean reward: 0.9894
# return standard deviation: 0.0244
# min return: 0.7919; max return: 1.0000
#
# episode 292 in 0.48 sec
# mean reward: 0.9891
# return standard deviation: 0.0291
# min return: 0.6391; max return: 1.0000
#
# episode 293 in 0.47 sec
# mean reward: 0.9877
# return standard deviation: 0.0352
# min return: 0.6502; max return: 0.9999
#
# episode 294 in 0.48 sec
# mean reward: 0.9897
# return standard deviation: 0.0213
# min return: 0.7500; max return: 1.0000
#
# episode 295 in 0.48 sec
# mean reward: 0.9884
# return standard deviation: 0.0250
# min return: 0.8019; max return: 0.9999
#
# episode 296 in 0.48 sec
# mean reward: 0.9906
# return standard deviation: 0.0185
# min return: 0.8069; max return: 1.0000
#
# episode 297 in 0.48 sec
# mean reward: 0.9890
# return standard deviation: 0.0284
# min return: 0.6536; max return: 1.0000
#
# episode 298 in 0.48 sec
# mean reward: 0.9849
# return standard deviation: 0.0489
# min return: 0.5715; max return: 1.0000
#
# episode 299 in 0.48 sec
# mean reward: 0.9889
# return standard deviation: 0.0235
# min return: 0.7824; max return: 1.0000
#
# episode 300 in 0.48 sec
# mean reward: 0.9846
# return standard deviation: 0.0437
# min return: 0.5769; max return: 1.0000
#
# episode 301 in 0.48 sec
# mean reward: 0.9878
# return standard deviation: 0.0335
# min return: 0.6326; max return: 1.0000
#
# episode 302 in 0.48 sec
# mean reward: 0.9854
# return standard deviation: 0.0428
# min return: 0.5918; max return: 0.9999
#
# episode 303 in 0.47 sec
# mean reward: 0.9882
# return standard deviation: 0.0380
# min return: 0.5858; max return: 1.0000
#
# episode 304 in 0.47 sec
# mean reward: 0.9865
# return standard deviation: 0.0419
# min return: 0.6406; max return: 1.0000
#
# episode 305 in 0.47 sec
# mean reward: 0.9889
# return standard deviation: 0.0363
# min return: 0.5700; max return: 1.0000
#
# episode 306 in 0.47 sec
# mean reward: 0.9921
# return standard deviation: 0.0208
# min return: 0.7335; max return: 0.9999
#
# episode 307 in 0.48 sec
# mean reward: 0.9895
# return standard deviation: 0.0306
# min return: 0.7298; max return: 1.0000
#
# episode 308 in 0.47 sec
# mean reward: 0.9886
# return standard deviation: 0.0299
# min return: 0.7435; max return: 1.0000
#
# episode 309 in 0.49 sec
# mean reward: 0.9914
# return standard deviation: 0.0215
# min return: 0.7249; max return: 1.0000
#
# episode 310 in 0.48 sec
# mean reward: 0.9895
# return standard deviation: 0.0258
# min return: 0.7354; max return: 1.0000
#
# episode 311 in 0.47 sec
# mean reward: 0.9913
# return standard deviation: 0.0178
# min return: 0.8403; max return: 1.0000
#
# episode 312 in 0.47 sec
# mean reward: 0.9928
# return standard deviation: 0.0136
# min return: 0.8496; max return: 1.0000
#
# episode 313 in 0.48 sec
# mean reward: 0.9910
# return standard deviation: 0.0236
# min return: 0.6748; max return: 1.0000
#
# episode 314 in 0.48 sec
# mean reward: 0.9901
# return standard deviation: 0.0259
# min return: 0.7788; max return: 1.0000
#
# episode 315 in 0.48 sec
# mean reward: 0.9889
# return standard deviation: 0.0276
# min return: 0.7530; max return: 1.0000
#
# episode 316 in 0.48 sec
# mean reward: 0.9919
# return standard deviation: 0.0160
# min return: 0.8575; max return: 1.0000
#
# episode 317 in 0.48 sec
# mean reward: 0.9904
# return standard deviation: 0.0296
# min return: 0.6348; max return: 1.0000
#
# episode 318 in 0.48 sec
# mean reward: 0.9869
# return standard deviation: 0.0360
# min return: 0.6786; max return: 1.0000
#
# episode 319 in 0.50 sec
# mean reward: 0.9902
# return standard deviation: 0.0232
# min return: 0.7971; max return: 1.0000
#
# episode 320 in 0.48 sec
# mean reward: 0.9929
# return standard deviation: 0.0136
# min return: 0.8650; max return: 1.0000
#
# episode 321 in 0.49 sec
# mean reward: 0.9916
# return standard deviation: 0.0189
# min return: 0.8242; max return: 1.0000
#
# episode 322 in 0.49 sec
# mean reward: 0.9918
# return standard deviation: 0.0218
# min return: 0.7188; max return: 1.0000
#
# episode 323 in 0.48 sec
# mean reward: 0.9878
# return standard deviation: 0.0339
# min return: 0.6298; max return: 1.0000
#
# episode 324 in 0.48 sec
# mean reward: 0.9860
# return standard deviation: 0.0399
# min return: 0.6416; max return: 1.0000
#
# episode 325 in 0.49 sec
# mean reward: 0.9903
# return standard deviation: 0.0201
# min return: 0.8039; max return: 1.0000
#
# episode 326 in 0.48 sec
# mean reward: 0.9864
# return standard deviation: 0.0366
# min return: 0.6407; max return: 1.0000
#
# episode 327 in 0.49 sec
# mean reward: 0.9886
# return standard deviation: 0.0250
# min return: 0.7867; max return: 1.0000
#
# episode 328 in 0.49 sec
# mean reward: 0.9856
# return standard deviation: 0.0378
# min return: 0.6661; max return: 1.0000
#
# episode 329 in 0.49 sec
# mean reward: 0.9905
# return standard deviation: 0.0241
# min return: 0.6695; max return: 0.9999
#
# episode 330 in 0.49 sec
# mean reward: 0.9891
# return standard deviation: 0.0270
# min return: 0.7164; max return: 1.0000
#
# episode 331 in 0.48 sec
# mean reward: 0.9915
# return standard deviation: 0.0167
# min return: 0.8113; max return: 1.0000
#
# episode 332 in 0.49 sec
# mean reward: 0.9873
# return standard deviation: 0.0373
# min return: 0.6220; max return: 1.0000
#
# episode 333 in 0.49 sec
# mean reward: 0.9910
# return standard deviation: 0.0174
# min return: 0.8374; max return: 1.0000
#
# episode 334 in 0.49 sec
# mean reward: 0.9902
# return standard deviation: 0.0251
# min return: 0.6583; max return: 1.0000
#
# episode 335 in 0.49 sec
# mean reward: 0.9894
# return standard deviation: 0.0216
# min return: 0.8304; max return: 1.0000
#
# episode 336 in 0.48 sec
# mean reward: 0.9882
# return standard deviation: 0.0299
# min return: 0.7757; max return: 1.0000
#
# episode 337 in 0.49 sec
# mean reward: 0.9885
# return standard deviation: 0.0400
# min return: 0.5873; max return: 1.0000
#
# episode 338 in 0.49 sec
# mean reward: 0.9907
# return standard deviation: 0.0213
# min return: 0.8016; max return: 1.0000
#
# episode 339 in 0.49 sec
# mean reward: 0.9868
# return standard deviation: 0.0378
# min return: 0.6630; max return: 1.0000
#
# episode 340 in 0.48 sec
# mean reward: 0.9910
# return standard deviation: 0.0240
# min return: 0.7504; max return: 1.0000
#
# episode 341 in 0.48 sec
# mean reward: 0.9895
# return standard deviation: 0.0252
# min return: 0.7436; max return: 1.0000
#
# episode 342 in 0.49 sec
# mean reward: 0.9880
# return standard deviation: 0.0410
# min return: 0.5488; max return: 1.0000
#
# episode 343 in 0.49 sec
# mean reward: 0.9870
# return standard deviation: 0.0393
# min return: 0.6408; max return: 0.9999
#
# episode 344 in 0.50 sec
# mean reward: 0.9897
# return standard deviation: 0.0299
# min return: 0.6921; max return: 1.0000
#
# episode 345 in 0.49 sec
# mean reward: 0.9918
# return standard deviation: 0.0243
# min return: 0.6314; max return: 1.0000
#
# episode 346 in 0.48 sec
# mean reward: 0.9894
# return standard deviation: 0.0233
# min return: 0.7997; max return: 1.0000
#
# episode 347 in 0.48 sec
# mean reward: 0.9902
# return standard deviation: 0.0232
# min return: 0.7102; max return: 1.0000
#
# episode 348 in 0.48 sec
# mean reward: 0.9910
# return standard deviation: 0.0229
# min return: 0.7765; max return: 1.0000
#
# episode 349 in 0.49 sec
# mean reward: 0.9896
# return standard deviation: 0.0291
# min return: 0.6091; max return: 0.9999
#
# episode 350 in 0.49 sec
# mean reward: 0.9904
# return standard deviation: 0.0233
# min return: 0.8003; max return: 1.0000
#
# episode 351 in 0.49 sec
# mean reward: 0.9902
# return standard deviation: 0.0232
# min return: 0.7431; max return: 1.0000
#
# episode 352 in 0.49 sec
# mean reward: 0.9883
# return standard deviation: 0.0338
# min return: 0.6807; max return: 1.0000
#
# episode 353 in 0.49 sec
# mean reward: 0.9902
# return standard deviation: 0.0320
# min return: 0.5578; max return: 1.0000
#
# episode 354 in 0.48 sec
# mean reward: 0.9892
# return standard deviation: 0.0382
# min return: 0.5233; max return: 1.0000
#
# episode 355 in 0.49 sec
# mean reward: 0.9837
# return standard deviation: 0.0451
# min return: 0.6263; max return: 1.0000
#
# episode 356 in 0.49 sec
# mean reward: 0.9887
# return standard deviation: 0.0255
# min return: 0.8129; max return: 1.0000
#
# episode 357 in 0.49 sec
# mean reward: 0.9852
# return standard deviation: 0.0368
# min return: 0.7254; max return: 1.0000
#
# episode 358 in 0.49 sec
# mean reward: 0.9915
# return standard deviation: 0.0201
# min return: 0.7218; max return: 0.9999
#
# episode 359 in 0.49 sec
# mean reward: 0.9907
# return standard deviation: 0.0229
# min return: 0.7449; max return: 1.0000
#
# episode 360 in 0.50 sec
# mean reward: 0.9899
# return standard deviation: 0.0334
# min return: 0.5692; max return: 1.0000
#
# episode 361 in 0.48 sec
# mean reward: 0.9893
# return standard deviation: 0.0284
# min return: 0.6979; max return: 1.0000
#
# episode 362 in 0.50 sec
# mean reward: 0.9893
# return standard deviation: 0.0347
# min return: 0.5716; max return: 1.0000
#
# episode 363 in 0.49 sec
# mean reward: 0.9901
# return standard deviation: 0.0253
# min return: 0.6787; max return: 1.0000
#
# episode 364 in 0.48 sec
# mean reward: 0.9890
# return standard deviation: 0.0252
# min return: 0.8091; max return: 1.0000
#
# episode 365 in 0.49 sec
# mean reward: 0.9883
# return standard deviation: 0.0344
# min return: 0.6220; max return: 1.0000
#
# episode 366 in 0.49 sec
# mean reward: 0.9904
# return standard deviation: 0.0291
# min return: 0.5831; max return: 0.9999
#
# episode 367 in 0.49 sec
# mean reward: 0.9865
# return standard deviation: 0.0408
# min return: 0.5328; max return: 1.0000
#
# episode 368 in 0.49 sec
# mean reward: 0.9883
# return standard deviation: 0.0260
# min return: 0.7780; max return: 1.0000
#
# episode 369 in 0.49 sec
# mean reward: 0.9887
# return standard deviation: 0.0282
# min return: 0.6873; max return: 1.0000
#
# episode 370 in 0.50 sec
# mean reward: 0.9886
# return standard deviation: 0.0278
# min return: 0.7369; max return: 1.0000
#
# episode 371 in 0.49 sec
# mean reward: 0.9888
# return standard deviation: 0.0280
# min return: 0.6836; max return: 1.0000
#
# episode 372 in 0.49 sec
# mean reward: 0.9929
# return standard deviation: 0.0087
# min return: 0.9133; max return: 1.0000
#
# episode 373 in 0.48 sec
# mean reward: 0.9900
# return standard deviation: 0.0210
# min return: 0.7793; max return: 1.0000
#
# episode 374 in 0.49 sec
# mean reward: 0.9899
# return standard deviation: 0.0337
# min return: 0.5817; max return: 1.0000
#
# episode 375 in 0.49 sec
# mean reward: 0.9897
# return standard deviation: 0.0249
# min return: 0.7912; max return: 1.0000
#
# episode 376 in 0.49 sec
# mean reward: 0.9918
# return standard deviation: 0.0166
# min return: 0.8356; max return: 1.0000
#
# episode 377 in 0.49 sec
# mean reward: 0.9901
# return standard deviation: 0.0279
# min return: 0.6905; max return: 1.0000
#
# episode 378 in 0.49 sec
# mean reward: 0.9896
# return standard deviation: 0.0245
# min return: 0.7182; max return: 1.0000
#
# episode 379 in 0.49 sec
# mean reward: 0.9881
# return standard deviation: 0.0375
# min return: 0.5312; max return: 1.0000
#
# episode 380 in 0.48 sec
# mean reward: 0.9888
# return standard deviation: 0.0326
# min return: 0.6016; max return: 1.0000
#
# episode 381 in 0.49 sec
# mean reward: 0.9921
# return standard deviation: 0.0158
# min return: 0.8202; max return: 1.0000
#
# episode 382 in 0.49 sec
# mean reward: 0.9897
# return standard deviation: 0.0322
# min return: 0.6472; max return: 1.0000
#
# episode 383 in 0.48 sec
# mean reward: 0.9875
# return standard deviation: 0.0375
# min return: 0.6275; max return: 1.0000
#
# episode 384 in 0.49 sec
# mean reward: 0.9917
# return standard deviation: 0.0171
# min return: 0.8481; max return: 1.0000
#
# episode 385 in 0.49 sec
# mean reward: 0.9902
# return standard deviation: 0.0273
# min return: 0.7712; max return: 1.0000
#
# episode 386 in 0.49 sec
# mean reward: 0.9917
# return standard deviation: 0.0285
# min return: 0.5745; max return: 0.9999
#
# episode 387 in 0.49 sec
# mean reward: 0.9891
# return standard deviation: 0.0291
# min return: 0.6663; max return: 1.0000
#
# episode 388 in 0.49 sec
# mean reward: 0.9889
# return standard deviation: 0.0326
# min return: 0.6753; max return: 1.0000
#
# episode 389 in 0.49 sec
# mean reward: 0.9866
# return standard deviation: 0.0368
# min return: 0.6484; max return: 1.0000
#
# episode 390 in 0.49 sec
# mean reward: 0.9877
# return standard deviation: 0.0380
# min return: 0.6557; max return: 1.0000
#
# episode 391 in 0.49 sec
# mean reward: 0.9902
# return standard deviation: 0.0312
# min return: 0.6993; max return: 1.0000
#
# episode 392 in 0.49 sec
# mean reward: 0.9914
# return standard deviation: 0.0189
# min return: 0.7642; max return: 1.0000
#
# episode 393 in 0.48 sec
# mean reward: 0.9910
# return standard deviation: 0.0240
# min return: 0.6797; max return: 1.0000
#
# episode 394 in 0.48 sec
# mean reward: 0.9920
# return standard deviation: 0.0126
# min return: 0.8993; max return: 1.0000
#
# episode 395 in 0.49 sec
# mean reward: 0.9891
# return standard deviation: 0.0319
# min return: 0.6153; max return: 1.0000
#
# episode 396 in 0.49 sec
# mean reward: 0.9864
# return standard deviation: 0.0422
# min return: 0.6198; max return: 1.0000
#
# episode 397 in 0.48 sec
# mean reward: 0.9914
# return standard deviation: 0.0245
# min return: 0.6517; max return: 1.0000
#
# episode 398 in 0.48 sec
# mean reward: 0.9892
# return standard deviation: 0.0368
# min return: 0.6549; max return: 1.0000
#
# episode 399 in 0.49 sec
# mean reward: 0.9899
# return standard deviation: 0.0307
# min return: 0.7462; max return: 1.0000
#
# episode 400 in 0.49 sec
# mean reward: 0.9875
# return standard deviation: 0.0342
# min return: 0.7132; max return: 1.0000

# %% [markdown]
# ## Plot the training curves
#
# Plot the mean final reward at each episode, and its variance. What do you observe?

# %%
import matplotlib
from matplotlib import pyplot as plt
# static plots
# %matplotlib inline 

### plot and examine learning curves

episodes=list(range(N_episodes))

plt.plot(episodes, mean_final_reward, '-k', label='mean final reward' )
plt.fill_between(episodes, 
                 mean_final_reward-0.5*std_final_reward, 
                 mean_final_reward+0.5*std_final_reward, 
                 color='k', 
                 alpha=0.25)

plt.plot(episodes, min_final_reward, '--b' , label='min final reward' )
plt.plot(episodes, max_final_reward, '--r' , label='max final reward' )

plt.xlabel('episode')
plt.ylabel('final reward')

plt.legend(loc='lower right')
plt.grid()
plt.tight_layout()

plt.savefig('RL_1q_training_curve.pdf',format="pdf")
plt.show()

# np.savez('PG-1_qubit_training',
#               episodes=episodes, 
#               mean_final_reward=mean_final_reward, 
#               std_final_reward=std_final_reward, 
#               min_final_reward=min_final_reward,
#               max_final_reward=max_final_reward,
#          )

# %% [markdown]
# Let us now investigate the agent's behavior starting from the south pole:

# %%
initial_states = [np.array([np.pi, 0.0]), 
                  # np.array([2*np.pi/3, 1.5*np.pi/2]), 
                  # np.array([np.pi/2, np.pi/2]), 
                  # np.array([np.pi/3, 0.857*np.pi])
                 ]

states_visited=np.zeros((len(initial_states),n_time_steps+1,2), dtype=np.complex128)
times = np.zeros((len(initial_states),n_time_steps+1),)

#env.reset(random=False) # start from south pole of Bloch sphere (cf. env)

for i, init_state in enumerate(initial_states):

    gates_applied=np.zeros((n_time_steps,2,2),dtype=np.complex128)
    protocol=[]

    env.reset()
    env.state=init_state
    env.psi=env.RL_to_qubit_state(env.state)
    
    done=False
    j=0
    while j < n_time_steps:
        
        # select state
        state[:] = env.state[:]

        # store data
        states_visited[i,j,:] = env.RL_to_qubit_state(state)
        times[i,j] = j*env.delta_t
    
        # select an action according to current policy
        pi_s = np.exp( predict(current_params, state) )
        action = np.random.choice(env.actions, p = pi_s)
        gates_applied[j,...] = env.action_space[action] 
        protocol.append(list(env.gate_generators.keys())[action])
        
        # take an environment step
        state=env.state.copy()
        next_state, reward, done = env.step(action)
        
        print("{}. s={}, a={}, r={}, s'={}\n".format(j, state, action, np.round(reward,6), next_state))
        
        j+=1
        
        if done:
            print('\nreached terminal state!')
            break

    # store final data
    states_visited[i,j,:] = env.RL_to_qubit_state(next_state)
    times[i,j] = j*env.delta_t
    
    print('generators of learned protocol for initial state {0}:\n{1}\n\n'.format(i,protocol) )

# np.savez('PG-1_learned_states',
#               states_visited=states_visited,
#               times=times
#          )
# Out:
# 0. s=[3.14 0.  ], a=5, r=0.010926, s'=[2.93 0.  ]
#
# 1. s=[2.93 0.  ], a=5, r=0.043227, s'=[2.72 0.  ]
#
# 2. s=[2.72 0.  ], a=5, r=0.095492, s'=[2.51 0.  ]
#
# 3. s=[2.51 0.  ], a=5, r=0.165435, s'=[2.3 0. ]
#
# 4. s=[2.3 0. ], a=5, r=0.25, s'=[2.09 0.  ]
#
# 5. s=[2.09 0.  ], a=5, r=0.345492, s'=[1.88 0.  ]
#
# 6. s=[1.88 0.  ], a=5, r=0.447736, s'=[1.68 0.  ]
#
# 7. s=[1.68 0.  ], a=5, r=0.552264, s'=[1.47 0.  ]
#
# 8. s=[1.47 0.  ], a=5, r=0.654508, s'=[1.26 0.  ]
#
# 9. s=[1.26 0.  ], a=5, r=0.75, s'=[1.05 0.  ]
#
# 10. s=[1.05 0.  ], a=5, r=0.834565, s'=[0.84 0.  ]
#
# 11. s=[0.84 0.  ], a=5, r=0.904508, s'=[0.63 0.  ]
#
# 12. s=[0.63 0.  ], a=5, r=0.956773, s'=[0.42 0.  ]
#
# 13. s=[0.42 0.  ], a=5, r=0.989074, s'=[0.21 0.  ]
#
# 14. s=[0.21 0.  ], a=5, r=1.0, s'=[0.   3.14]
#
# generators of learned protocol for initial state 0:
# ['-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y', '-Y']

# %% [markdown]
# ## Questions
#
# **Q0.** Try out different batch sizes and hyperparameters (including different network architectures). Can you improve the performance?
#
# **Q1.** Explore the final batch of trajectories. Check the sequence of actions. Can you make sense of the solution found by the agent? _Hint: think of the dynamics on the Bloch sphere and try to visualize the trajectory there._
#
# **Q2.** Compare the Policy Gradient method to conventional optimal control: can optimal control give you a control protocol that works for all initial states? Why or why not?
#
# **Q3.** Take one of the high-reward trajectories in the final batch of data. Now perturb it manually at a few time steps in the first half of the protocol such that it no longer produces an optimal reward (you would have to add a function to the environment that evalues a given trajectory). Last, use the policy to see how it would react to those perturbations in real-time. Will it correct for the introduced mistakes online (i.e., on the fly or before the episode is over)?
#
# **Q4.** Find ways to visualize the policy for each state of the Bloch sphere. What is a meaningful way to do that?

# %% [markdown]
# ## Advanced Problems
#
# **A0.** What is the initial state distribution $p(s_0)$ in the implementation above? Check the performance of the PG algorithm if $p(s_0)$ is
#     * a delta distribution;
#     * a compactly-supported uniform distribution over some sector of the sphere (say a cap around the south pole);
#     * a Gaussian distribution with non-compact support (here you can study the performance as a function of the standard deviation).
#
# **A1.** Introduce small Gaussian noise to the rewards, e.g., $r(s,a) \to r(s,a) + \delta r$ where $\delta r \sim \mathcal{N}(0,\delta)$ for some noise strength $\delta$. Does this lead to a serious performance drop as you vary $\delta\in[0,0.5]$? Why or why not?
#
# **A2.** The loop over the $N_{MC}$ trajectories slows down the algorithm significantly. Consider ways to speed up the evaluation of a single PG iteration. This can include a modification of the environment `QubitEnv` or the use of parallelization software (see JAX's functions [`vmap`](https://jax.readthedocs.io/en/latest/jax.html#vectorization-vmap) and [`pmap`](https://jax.readthedocs.io/en/latest/jax.html#parallelization-pmap)).
#
# **A3.** Change the environment `QubitEnv` to define a nonepisodic task (i.e., a task that continues until the terminal state $s_\mathrm{target}$ is reached and does _not_ have a fixed number of steps). In doing so, introduce an additional "stop" action so that when the agent brings the RL state close to $s_\mathrm{target}$ the episode comes to an end and the environment is reset. This would require you to also modify the Policy Gradient implementation above because episodes now can have different lengths.
